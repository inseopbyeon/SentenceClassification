# %% [markdown]
# # LSTM, GRU, 1D CNN MODEL 비교

# %%
# GPU로 Tesla T4가 준비돼있습니다.
# !nvidia-smi
# Out:
# Tue Jun 25 03:31:52 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.239.06   Driver Version: 470.239.06   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0    33W /  70W |   1707MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import wandb
from wandb.keras import WandbCallback
from sklearn.preprocessing import LabelEncoder
import json

# %% [markdown]
# # 1. 데이터 가져오기

# %%
train_data_path ="~/aiffel/dktc/data/train.csv"
data = pd.read_csv(train_data_path)
data.head()
# Out:
#    idx      class                                       conversation
# 0    0      협박 대화  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...
# 1    1      협박 대화  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...
# 2    2  기타 괴롭힘 대화  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...
# 3    3      갈취 대화  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...
# 4    4      갈취 대화  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...

# %%
data.shape
# Out:
# (3950, 3)

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ### 2-1)결측치, 중복데이터 확인

# %%
print(data.isna().sum())
# Out:
# idx             0
# class           0
# conversation    0
# dtype: int64

# %%
#중복인 행 확인
data['duplicates'] = data.duplicated(['conversation'])
data[data['duplicates'] == True]
# Out:
#        idx        class                                       conversation  \
# 392    392    기타 괴롭힘 대화  병신이 아이스크림 먹게 돼 있냐?\n난 먹으면 안 돼? 그만 좀 해.\n당연히 안 ...
# 523    523  직장 내 괴롭힘 대화  과장님. 저 이번에 휴가 좀 갔다와도 되겠습니까.?\n휴가? 왜??\n좀 쉬다가 오...
# 789    789    기타 괴롭힘 대화  야 얘 이 쪽 손가락 세 개밖에 없다\n엥 손가락이 세개밖에 없을 수가 있어?\n봐...
# 824    824    기타 괴롭힘 대화  이야 내동생 여자친구한테 편지쓰네?\n 아 형 돌려줘.\n 어디보자. 사랑하는 여친...
# 869    869  직장 내 괴롭힘 대화  지현씨 나 소개팅 좀 시켜줘봐\n네? 저 주변에 아는 사람이 없어서요\n아 상사라 ...
# ...    ...          ...                                                ...
# 3797  3797    기타 괴롭힘 대화  너 이번 방학 때 쌍꺼풀 수술 하고왔지?\n아닌데?\n아니긴 뭐가 아니야. 눈이 이...
# 3798  3798    기타 괴롭힘 대화  안녕하세요 지금 먹방 촬영중인데 촬영가능할까요?\n안돼요\n한번만 안될까요?\n안돼...
# 3855  3855    기타 괴롭힘 대화  그 소문 진짜야? 너가 다른 애들 뒷담화하고 다녔다며?\n응? 나 그런 적 없는데?...
# 3874  3874    기타 괴롭힘 대화  야 니 왤캐 못생겼냐?\n뭐라그랬냐?\n으 나 보고 말하지마 니 얼굴보면 토나올거 ...
# 3928  3928    기타 괴롭힘 대화  새파랗게 젊은게 어디 여길 앉아있어\n저 임산부에요\n사지 멀쩡한게! 임신이 벼슬이...
#
#       duplicates
# 392         True
# 523         True
# 789         True
# 824         True
# 869         True
# ...          ...
# 3797        True
# 3798        True
# 3855        True
# 3874        True
# 3928        True
#
# [104 rows x 4 columns]

# %%
#중복제거
data = data.drop_duplicates(['conversation'])

# %%
#conversation과 class만 남김
data = data[['conversation','class']]
data.head()
# Out:
#                                         conversation      class
# 0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...      협박 대화
# 1  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...      협박 대화
# 2  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...  기타 괴롭힘 대화
# 3  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...      갈취 대화
# 4  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...      갈취 대화

# %%
data.shape
# Out:
# (3846, 2)

# %% [markdown]
# ### 2-2)레이블인코딩

# %%
CLASS_NAMES = ['협박 대화', '갈취 대화', '직장 내 괴롭힘 대화', '기타 괴롭힘 대화']

encoder = LabelEncoder()
encoder.fit(CLASS_NAMES)

data['class'] = encoder.transform(data['class'])

corpus = data["conversation"]
data.head()
# Out:
#                                         conversation  class
# 0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...      3
# 1  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...      3
# 2  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...      1
# 3  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...      0
# 4  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...      0

# %% [markdown]
# ### 2-3)토크나이저 및 단어사전 생성

# %%
def tokenize(corpus):
    #토크나이저 객체생성
    tokenizer = tf.keras.preprocessing.text.Tokenizer(
        num_words=1000, 
        filters=' ',
        oov_token="<unk>")
    
    tokenizer.fit_on_texts(corpus) #corpus 기준으로 단어 사전 생성
    tensor = tokenizer.texts_to_sequences(corpus) #정수시퀀스
    
    #시퀀스패딩
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, 
                                                           padding='post',
                                                           maxlen=20) #최대길이
    print(tensor,tokenizer)
    return tensor, tokenizer

#데이터셋에서 토큰화 및 패딩작업 결과를 저장
tensor, tokenizer = tokenize(corpus)
# Out:
# [[  1 210   1 ...   1  42   1]
#  [  1   1   1 ...   1   1 401]
#  [  1  97   1 ...   1 136   1]
#  ...
#  [495   3 110 ...  27   1   1]
#  [  1   1 151 ... 348   1   1]
#  [  1   1   1 ... 159 113   1]] <keras_preprocessing.text.Tokenizer object at 0x7fa3185f0ac0>

# %% [markdown]
# ### 2-4)데이터 분할

# %%
#Train data와 Test data 분할
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tensor, data['class'], 
                                                    test_size=0.1, 
                                                    stratify = data['class'], 
                                                    random_state=42)

# %% [markdown]
# # 3. 모델생성 및 훈련

# %% [markdown]
# ## 3-1) 모델 구성

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,SimpleRNN, LSTM, GRU, Conv1D, GlobalMaxPooling1D, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

vocab_size = 1000  # 어휘 사전의 크기
word_vector_dim = 20  # 단어 하나를 표현하는 임베딩 벡터의 차원수

#RNN 모델 생성
def create_rnn_model(vocab_size, word_vector_dim):
    model = Sequential()
    model.add(Embedding(vocab_size, word_vector_dim, input_length=None))
    model.add(SimpleRNN(256)) 
    model.add(Dropout(0.2)) 
    model.add(Dense(64, activation='relu'))
    model.add(Dense(4, activation='softmax')) 
    return model

#LSTM 모델생성
def create_lstm_model(vocab_size, word_vector_dim):
    model = Sequential()
    model.add(Embedding(vocab_size, word_vector_dim, input_length=None))
    model.add(LSTM(256)) 
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(4, activation='softmax'))
    return model

#GRU 모델생성
def create_gru_model(vocab_size, word_vector_dim):
    model = Sequential()
    model.add(Embedding(vocab_size, word_vector_dim, input_length=None))
    model.add(GRU(256)) 
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(4, activation='softmax'))
    return model

#CNN 모델생성
def create_1d_cnn_model(vocab_size, word_vector_dim):
    model = Sequential()
    model.add(Embedding(vocab_size, word_vector_dim, input_length=None))
    model.add(Conv1D(256, 3, activation='relu')) 
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(4, activation='softmax'))  
    return model

# %%
# R1 Score 함수정의
import tensorflow as tf

def f1_score(y_true, y_pred):
    # 예측값 중 가장 높은 확률을 가진 클래스 인덱스 추출
    pred_top_k = tf.math.argmax(y_pred, axis=-1)

    # 실제 정답 클래스 인덱스 추출 (원-핫 인코딩된 경우)
    true_top_k = tf.math.argmax(y_true, axis=-1)

    # 예측값과 실제 정답이 일치하는 경우 True, 아니면 False
    correct = tf.math.equal(pred_top_k, true_top_k)

    # True 개수를 전체 데이터 개수로 나눠 R1 계산
    return tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
#콜백함수
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',  # 검증 손실을 기준으로 조기 종료 여부 판단
    patience=5,         # 검증 손실이 개선되지 않는 epoch를 5회까지 허용
    restore_best_weights=True  # 가장 좋은 검증 손실을 낸 모델의 가중치 복원
)

# %%
#모델 함수 배열로 가져오김
models = [create_rnn_model(vocab_size, word_vector_dim),
          create_lstm_model(vocab_size, word_vector_dim), 
          create_gru_model(vocab_size, word_vector_dim), 
          create_1d_cnn_model(vocab_size, word_vector_dim)]
model_names = ['RNN', 'LSTM', 'GRU', '1D CNN']

# %% [markdown]
# ## 3-2) 모델학습 및 평가

# %%
import matplotlib.pyplot as plt
import numpy as np

#kfold 객체생성
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
 
# 훈련 및 평가 기록할 배열
histories = []
losses = []
accuracies = []
f1s = []

# 시드 값 리스트
random_states = [42, 123, 456, 789]  # 사용할 시드 값들을 리스트에 추가

#모든 모델 학습 및 평가
for model in models:
    
    #fold별 loss, accuracy, f1 score기록
    fold_losses = []
    fold_accuracies = []
    fold_f1s = []
    
    for seed in random_states:
        
        # 시드 값 설정
        np.random.seed(seed)
        tf.random.set_seed(seed) #
    
        #K겹 교차검증
        for train_index, val_index in skf.split(X_train, y_train):

            #데이터 분할
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train.values[train_index], y_train.values[val_index]

            model.compile(optimizer='adam', 
                          loss='sparse_categorical_crossentropy', 
                          metrics=['accuracy',f1_score])

            history = model.fit(X_train_fold, y_train_fold, epochs=50, 
                                validation_data=(X_val_fold, y_val_fold), 
                                callbacks = [early_stopping])

            #모델 평가
            loss, accuracy, f1  = model.evaluate(X_test, y_test)

            #fold별 평가 결과를 배열에 기록
            fold_losses.append(loss)
            fold_accuracies.append(accuracy)
            fold_f1s.append(f1)

        avg_loss = np.mean(fold_losses)
        avg_accuracy = np.mean(fold_accuracies)
    avg_f1 = np.mean(fold_f1s)
    
    losses.append(avg_loss)
    accuracies.append(avg_accuracy)
    f1s.append(avg_f1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - 3s 23ms/step - loss: 1.3950 - accuracy: 0.2598 - f1_score: 0.2267 - val_loss: 1.3818 - val_accuracy: 0.2742 - val_f1_score: 0.0341
# Epoch 2/50
50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3186 - accuracy: 0.8909 - f1_score: 0.2482 - val_loss: 1.4840 - val_accuracy: 0.5844 - val_f1_score: 0.2096
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9615 - accuracy: 0.5922 - f1_score: 0.2308
# Epoch 1/50
# 87/87 [==============================] - 1s 6ms/step - loss: 0.7802 - accuracy: 0.6959 - f1_score: 0.2320 - val_loss: 0.6729 - val_accuracy: 0.7413 - val_f1_score: 0.2034
# Epoch 2/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6637 - accuracy: 0.7591 - f1_score: 0.2316 - val_loss: 0.6971 - val_accuracy: 0.7399 - val_f1_score: 0.2134
# Epoch 3/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5802 - accuracy: 0.7956 - f1_score: 0.2341 - val_loss: 0.7514 - val_accuracy: 0.7052 - val_f1_score: 0.2361
# Epoch 4/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.8209 - f1_score: 0.2456 - val_loss: 0.8068 - val_accuracy: 0.7038 - val_f1_score: 0.2347
# Epoch 5/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4496 - accuracy: 0.8440 - f1_score: 0.2444 - val_loss: 0.8874 - val_accuracy: 0.6850 - val_f1_score: 0.1977
# Epoch 6/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3862 - accuracy: 0.8660 - f1_score: 0.2476 - val_loss: 0.9971 - val_accuracy: 0.6749 - val_f1_score: 0.1969
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9563 - accuracy: 0.6078 - f1_score: 0.1851
# Epoch 1/50
# 87/87 [==============================] - 1s 5ms/step - loss: 0.7108 - accuracy: 0.7212 - f1_score: 0.2366 - val_loss: 0.5950 - val_accuracy: 0.7717 - val_f1_score: 0.2116
# Epoch 2/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.6127 - accuracy: 0.7714 - f1_score: 0.2291 - val_loss: 0.6558 - val_accuracy: 0.7428 - val_f1_score: 0.2670
# Epoch 3/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5443 - accuracy: 0.7923 - f1_score: 0.2348 - val_loss: 0.6997 - val_accuracy: 0.7283 - val_f1_score: 0.2443
# Epoch 4/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4742 - accuracy: 0.8285 - f1_score: 0.2440 - val_loss: 0.7674 - val_accuracy: 0.7095 - val_f1_score: 0.2812
# Epoch 5/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4213 - accuracy: 0.8563 - f1_score: 0.2385 - val_loss: 0.8340 - val_accuracy: 0.6980 - val_f1_score: 0.2528
# Epoch 6/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3574 - accuracy: 0.8776 - f1_score: 0.2430 - val_loss: 0.9280 - val_accuracy: 0.6850 - val_f1_score: 0.2420
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9499 - accuracy: 0.6156 - f1_score: 0.1875
# Epoch 1/50
# 87/87 [==============================] - 1s 5ms/step - loss: 0.6620 - accuracy: 0.7526 - f1_score: 0.2371 - val_loss: 0.5519 - val_accuracy: 0.8006 - val_f1_score: 0.2134
# Epoch 2/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5682 - accuracy: 0.7884 - f1_score: 0.2357 - val_loss: 0.6093 - val_accuracy: 0.7486 - val_f1_score: 0.2256
# Epoch 3/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4930 - accuracy: 0.8252 - f1_score: 0.2437 - val_loss: 0.6660 - val_accuracy: 0.7355 - val_f1_score: 0.2369
# Epoch 4/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4344 - accuracy: 0.8436 - f1_score: 0.2420 - val_loss: 0.7475 - val_accuracy: 0.7095 - val_f1_score: 0.2185
# Epoch 5/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3746 - accuracy: 0.8678 - f1_score: 0.2470 - val_loss: 0.8248 - val_accuracy: 0.6980 - val_f1_score: 0.2313
# Epoch 6/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3213 - accuracy: 0.8931 - f1_score: 0.2448 - val_loss: 0.9304 - val_accuracy: 0.6850 - val_f1_score: 0.2776
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9509 - accuracy: 0.6182 - f1_score: 0.1875
# Epoch 1/50
# 87/87 [==============================] - 1s 5ms/step - loss: 0.6017 - accuracy: 0.7718 - f1_score: 0.2332 - val_loss: 0.5480 - val_accuracy: 0.7861 - val_f1_score: 0.2125
# Epoch 2/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5050 - accuracy: 0.8176 - f1_score: 0.2376 - val_loss: 0.6006 - val_accuracy: 0.7688 - val_f1_score: 0.2545
# Epoch 3/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.8371 - f1_score: 0.2444 - val_loss: 0.6723 - val_accuracy: 0.7471 - val_f1_score: 0.2597
# Epoch 4/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3919 - accuracy: 0.8649 - f1_score: 0.2477 - val_loss: 0.7481 - val_accuracy: 0.7298 - val_f1_score: 0.2435
# Epoch 5/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3391 - accuracy: 0.8866 - f1_score: 0.2484 - val_loss: 0.8202 - val_accuracy: 0.7240 - val_f1_score: 0.2534
# Epoch 6/50
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2878 - accuracy: 0.9061 - f1_score: 0.2533 - val_loss: 0.9051 - val_accuracy: 0.7066 - val_f1_score: 0.2557
# 13/13 [==============================] - 0s 2ms/step - loss: 0.9757 - accuracy: 0.6182 - f1_score: 0.1755

# %%
losses
# Out:
# [1.389388871192932, 1.0188891172409058, 1.076064109802246, 0.9588764309883118]

# %%
for model, loss, acc, r1 in zip(model_names, losses ,accuracies ,r1s):
    print(f"{model} > Loss: {loss:0.5f}, Accuracy: {acc:0.5f}, F1 Score: {r1:0.5f}")
# Out:
# RNN > Loss: 1.38939, Accuracy: 0.43325, F1 Score: 0.36458
# LSTM > Loss: 1.01889, Accuracy: 0.57870, F1 Score: 0.27083
# GRU > Loss: 1.07606, Accuracy: 0.56364, F1 Score: 0.19792
# 1D CNN > Loss: 0.95888, Accuracy: 0.61039, F1 Score: 0.27083

# %% [markdown]
# # 분석 결과
#
# ### 1D CNN
#
# - 가장 낮은 Loss와 가장 높은 Accuracy를 보여 전반적으로 가장 좋은 성능을 나타냄
# - 지역적인 특징 추출에 강점을 가지는 CNN의 특성이 텍스트 분류 문제에 효과적으로 작용한 것으로 보임
#
# ### LSTM
#
# - RNN의 단점인 기울기 소실 문제를 완화하여 비교적 긴 시퀀스 데이터를 잘 처리함
# - 두 번째로 높은 Accuracy를 기록됨
#
# ### GRU
# - LSTM과 유사한 성능을 보임
#
# ### RNN
# - 가장 간단한 구조로 훈련 속도가 빠르지만, 기울기 소실 문제로 인해 긴 시퀀스 데이터 처리에 취약하며, 다른 모델들에 비해 성능이 떨어짐
#
# ## F1 점수
#
# 1D CNN과 LSTM 모델은 동일한 F1 점수를 갖지만, Accuracy가 더 높은 1D CNN 모델이 전반적으로 더 우수함
#  GRU 모델은 다른 모델들에 비해 낮은 F1 점수를 보여 개선의 여지가 있음
